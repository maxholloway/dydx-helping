# %%
# !pip freeze
# Out:
# aiohttp==3.8.1
# aiosignal==1.2.0
# appnope==0.1.2
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# asttokens==2.0.5
# async-timeout==4.0.2
# atomicwrites==1.4.0
# attrs==21.4.0
# backcall==0.2.0
# base58==2.1.1
# bitarray==1.2.2
# black==21.12b0
# bleach==4.1.0
# certifi==2021.10.8
# cffi==1.15.0
# charset-normalizer==2.0.10
# click==8.0.3
# cytoolz==0.11.2
# dateparser==1.0.0
# debugpy==1.5.1
# decorator==5.1.1
# defusedxml==0.7.1
# distlib==0.3.4
# dydx-v3-python==1.4.5
# ecdsa==0.16.0
# entrypoints==0.3
# eth-abi==2.1.1
# eth-account==0.5.6
# eth-hash==0.3.2
# eth-keyfile==0.5.1
# eth-keys==0.4.0
# eth-rlp==0.2.1
# eth-typing==3.0.0
# eth-utils==1.10.0
# executing==0.8.2
# filelock==3.4.2
# frozenlist==1.2.0
# hexbytes==0.2.2
# idna==3.3
# importlib-metadata==0.23
# ipfshttpclient==0.8.0a2
# ipykernel==6.7.0
# ipython==8.0.0
# ipython-genutils==0.2.0
# ipywidgets==7.6.5
# jedi==0.18.1
# Jinja2==3.0.3
# jsonschema==3.2.0
# jupyter==1.0.0
# jupyter-client==7.1.1
# ...

# %%
from dydx3 import Client

#
# Access public API endpoints.
#
public_client = Client(
    host='https://api.dydx.exchange/',
)
public_client.public.get_markets().data
# Out:
# {'markets': {'BTC-USD': {'market': 'BTC-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'BTC',
#    'quoteAsset': 'USD',
#    'stepSize': '0.0001',
#    'tickSize': '1',
#    'indexPrice': '43276.1350',
#    'oraclePrice': '43260.0000',
#    'priceChange24H': '-4.753000',
#    'nextFundingRate': '0.0000135656',
#    'nextFundingAt': '2022-01-15T22:00:00.000Z',
#    'minOrderSize': '0.001',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.05',
#    'maintenanceMarginFraction': '0.03',
#    'volume24H': '219912799.096100',
#    'trades24H': '34079',
#    'openInterest': '5253.3603',
#    'incrementalInitialMarginFraction': '0.01',
#    'incrementalPositionSize': '1.5',
#    'maxPositionSize': '170',
#    'baselinePositionSize': '9',
#    'assetResolution': '10000000000',
#    'syntheticAssetId': '0x4254432d3130000000000000000000'},
#   'SUSHI-USD': {'market': 'SUSHI-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'SUSHI',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
# ...
